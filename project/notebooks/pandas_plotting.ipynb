# %% [markdown]
# # Pandas
#
# High level tip -- try to represent data in the proper format: floats as floats; ints as ints; etc. Especially if you have dates, or timestamps, or datetimestamps, keep them in that format. The temptation to operate on them like strings may be overwhelming, but resist! In the long run you might prevail. :\

# %%
# %install_ext http://raw.github.com/jrjohansson/version_information/master/version_information.py
# %load_ext version_information
# %reload_ext version_information
# %version_information numpy, scipy, matplotlib, pandas
# Out:
# Software versions
# Python 2.7.11 64bit [GCC 4.2.1 (Apple Inc. build 5577)]
# IPython 4.0.1
# OS Darwin 14.5.0 x86_64 i386 64bit
# numpy 1.10.2
# scipy 0.16.1
# matplotlib 1.5.1
# pandas 0.17.1
# Wed Jan 20 12:33:00 2016 PST

# %%
# Doing this in python 2.7 code allows for most of the code to be python 3 portable.
# But you have to write your print functions: print("Hello world.")
# from __future__ import division, absolute_import, print_function, unicode_literals
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_context('talk')
sns.set_style('darkgrid') 
plt.rcParams['figure.figsize'] = 12, 8  # plotsize 


from pandas.tools.plotting import scatter_matrix
import numpy as np

from sklearn.datasets import load_boston
import pandas as pd
# Out:
# /Users/jonathan/miniconda2/envs/berkeley3/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %% [markdown]
# ### Note
#
# Using cleaned data from [Data Cleaning](Data%20Cleaning.ipynb) Notebook. See Notebook for details.

# %%
dframe = pd.read_csv("../data/coal_prod_cleaned.csv")

# %% [markdown]
# ## Notebook Extensions -- qgrid

# %%
# Check out http://nbviewer.ipython.org/github/quantopian/qgrid/blob/master/qgrid_demo.ipynb for more (including demo)
import qgrid # Best practices is to put imports at the top of the Notebook.
qgrid.nbinstall(overwrite=True)
# Out:
# /Users/jonathan/miniconda2/envs/berkeley3/lib/python2.7/site-packages/IPython/html.py:14: ShimWarning: The `IPython.html` package has been deprecated. You should import from `notebook` instead. `IPython.html.widgets` has moved to `ipywidgets`.
#   "`IPython.html.widgets` has moved to `ipywidgets`.", ShimWarning)

# %%
dframe.head()
# Out:
#    MSHA_ID  Average_Employees                   Company_Type  Labor_Hours  \
# 0   102838                  4  Independent Producer Operator         2712
# 1   103184                  5  Independent Producer Operator         2480
# 2   100329                 55           Operating Subsidiary       123618
# 3   100851                331           Operating Subsidiary       748182
# 4   102354                 28  Independent Producer Operator        55306
#
#             Mine_Basin Mine_County       Mine_Name Mine_State  \
# 0  Appalachia Southern        Bibb     Hebron Mine    Alabama
# 1  Appalachia Southern     Fayette      Berry Mine    Alabama
# 2  Appalachia Southern   Jefferson    Concord Mine    Alabama
# 3  Appalachia Southern   Jefferson  Oak Grove Mine    Alabama
# 4  Appalachia Southern   Jefferson       Lindbergh    Alabama
#
#              Mine_Status    Mine_Type               Operating_Company  \
# 0  Permanently abandoned      Surface  Birmingham Coal & Coke Company
# 1     Temporarily closed      Surface  Midas Coal Company Incorporate
# 2                 Active  Underground    U S Steel Mining Company Llc
# 3                 Active  Underground    U S Steel Mining Company Llc
# 4                 Active      Surface        C & H Mining Company Inc
#
#                          Operating_Company_Address     Operation_Type  \
# 0  2477 Valleydale Rd. S. B3, Birmingham, AL 35244          Mine only
# 1         401 10th Avenue, S. E, Cullman, AL 35055          Mine only
# 2        8800 Oak Grove Mine Road, Adger, AL 35006  Preparation Plant
# 3          8800 Oak Grove Mine Rd, Adger, AL 35006          Mine only
# 4             P.O. Box 70250, Tuscaloosa, AL 35407          Mine only
#
#    Production_short_tons                      Union_Code  Year
# 0                  10572                             NaN  2002
# 1                   9725                             NaN  2002
# 2                      0  United Mine Workers of America  2002
# 3                1942153  United Mine Workers of America  2002
# 4                 168446                             NaN  2002

# %%
qgrid.show_grid(dframe[['MSHA_ID', 'Year', 'Mine_Name', 'Mine_State', 'Mine_County']], remote_js=True)
# Out:
# <script type="text/javascript">
# if ($("#dg-css").length == 0){
#     $("head").append([
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick.grid.css' rel='stylesheet'>",
#         "<link href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//lib/slick-default-theme.css' rel='stylesheet'>",
#         "<link href='http://cdnjs.cloudflare.com/ajax/libs/jqueryui/1.10.4/css/jquery-ui.min.css' rel='stylesheet'>",
#         "<link id='dg-css' href='https://cdn.rawgit.com/quantopian/qgrid/72d356cb123fab413dba73ec46616e4916fbd827/qgrid/qgridjs//qgrid.css' rel='stylesheet'>"
#     ]);
# }
# </script>
# <div class='q-grid-container'>
# <div id='b348a70a-7eb7-4e50-a4fc-a44c81eb7800' class='q-grid'></div>
# </div>

# %%
df_dict = load_boston()
features = pd.DataFrame(data=df_dict.data, columns = df_dict.feature_names)
target = pd.DataFrame(data=df_dict.target, columns = ['MEDV'])
df = pd.concat([features, target], axis=1)
df.head()
# Out:
#       CRIM  ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# Target variable
fig, ax = plt.subplots(figsize=(10,8))
sns.distplot(df.MEDV, ax=ax, rug=True, hist=False)

# %%
fig, ax = plt.subplots(figsize=(10,7))
sns.kdeplot(df.LSTAT, df.MEDV,  ax=ax)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
scatter_matrix(df[['MEDV', 'LSTAT', 'CRIM', 'RM', 'NOX', 'DIS']], alpha=0.2, diagonal='hist', ax=ax);
