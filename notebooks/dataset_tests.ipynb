# %%
from typing import Any, Dict, Optional, Tuple, List
import numpy as np

import pandas as pd
import torch
from pytorch_lightning import LightningDataModule
from torch.utils.data import ConcatDataset, DataLoader, Dataset, SequentialSampler #random_split
from torch.nn.utils.rnn import pad_sequence
from torch.utils.data import Dataset
from torch import Tensor
import sqlite3
import math
from torch import default_generator, randperm
from torch._utils import _accumulate
from torch.utils.data.dataset import Subset
from torch_geometric.data import Data


def pad_collate(batch):
  (xx, y) = zip(*batch)
  x_lens = [len(x) for x in xx]
  print(x_lens)
  xx_pad = pad_sequence(xx, batch_first=True, padding_value=0)

  pad_mask = torch.zeros_like(xx_pad[:, :, 0]).type(torch.bool)
  for i, length in enumerate(x_lens):
    pad_mask[i, length:] = True

  return xx_pad, torch.tensor(y), pad_mask

class SimpleDataset(Dataset):
  def __init__(self, 
               db_path: str, 
               event_no_list: List[int], #event_no_list_path: str,
               pulsemap: str,
               input_cols: List[str],
               target_cols: List[str],
               truth_table: str = "truth"
               ):
    self.db_path = db_path
    self.event_no_list = event_no_list #self.event_no_list_path = event_no_list_path
    self.pulsemap = pulsemap
    self.input_cols = input_cols
    self.target_cols = target_cols
    self.truth_table = truth_table


    if isinstance(list(input_cols), list):
      self.input_cols_str = ", ".join(input_cols)
    else:

      self.input_cols_str = input_cols

    if isinstance(target_cols, list):
      self.target_cols_str = ", ".join(target_cols)
    else:
      self.target_cols_str = target_cols
    
    # self.event_no_list = np.genfromtxt(self.event_no_list_path,dtype=int)

    self.data_len = len(self.event_no_list)
    

  def __getitem__(self, index):
    event_no = self.event_no_list[index]
    with sqlite3.connect(self.db_path) as conn:
      features = Tensor(conn.execute(f"SELECT {self.input_cols_str} FROM {self.pulsemap} WHERE event_no == {event_no}").fetchall())
      truth = Tensor(conn.execute(f"SELECT {self.target_cols_str} FROM {self.truth_table} WHERE event_no == {event_no}").fetchall())
    return features, truth
  
  def __len__(self):
    return self.data_len

class SimpleIceCubeSQLDatamodule(LightningDataModule):
    """Example of LightningDataModule for MNIST dataset.

    A DataModule implements 5 key methods:

        def prepare_data(self):
            # things to do on 1 GPU/TPU (not on every GPU/TPU in DDP)
            # download data, pre-process, split, save to disk, etc...
        def setup(self, stage):
            # things to do on every process in DDP
            # load data, set variables, etc...
        def train_dataloader(self):
            # return train dataloader
        def val_dataloader(self):
            # return validation dataloader
        def test_dataloader(self):
            # return test dataloader
        def teardown(self):
            # called on every process in DDP
            # clean up after fit or test

    This allows you to share a full dataset without explaining how to download,
    split, transform and process the data.

    Read the docs:
        https://pytorch-lightning.readthedocs.io/en/latest/data/datamodule.html
    """

    def __init__(
        self,
        db_path: str = "/groups/icecube/petersen/GraphNetDatabaseRepository/Upgrade_Data/sqlite3/dev_step4_upgrade_028_with_noise_dynedge_pulsemap_v3_merger_aftercrash.db",
        event_no_list_path: str = "/groups/icecube/moust/storage/event_selections/event_no_numu_track_energy_15_200_nhits_4_400_sorted.csv",
        pulsemap: str = "SplitInIcePulses_dynedge_v2_Pulses",
        input_cols: List[str] = ["charge", "dom_time", "dom_x", "dom_y", "dom_z", "pmt_dir_x", "pmt_dir_y", "pmt_dir_z" ],
        target_cols: List[str] = "energy",
        truth_table: str = "truth",
        data_dir: str = "data/",
        # train_val_test_split: Tuple[float, float, float] = (0.8, 0.1, 0.1),# train_val_test_split_rate: Tuple[float, float, float] = (0.8, 0.1, 0.1),
        batch_size: int = 2,
        num_workers: int = 0,
        pin_memory: bool = False,
    ):
        super().__init__()

        self.db_path = db_path
        self.event_no_list_path = event_no_list_path
        self.pulsemap = pulsemap
        self.input_cols = input_cols
        self.target_cols = target_cols
        self.truth_table = truth_table
        self.data_dir = data_dir
        # train_val_test_split: Tuple[float, float, float] = (0.8, 0.1, 0.1),# train_val_test_split_rate: Tuple[float, float, float] = (0.8, 0.1, 0.1),
        self.batch_size = batch_size
        self.num_workers = num_workers
        self.pin_memory = pin_memory

        # this line allows to access init params with 'self.hparams' attribute
        # also ensures init params will be stored in ckpt
        # self.save_hyperparameters(logger=False)

        # data transformations here if any
        self.event_no_list = pd.read_csv(event_no_list_path,header=0,names=["event_no"],index_col=None)["event_no"].to_numpy()

        # self.event_no_list = np.genfromtxt(self.hparams.event_no_list_path,dtype=int)
    
        self.data_train: Optional[Dataset] = None
        self.data_val: Optional[Dataset] = None
        self.data_test: Optional[Dataset] = None

    # @property
    # def num_classes(self):
    #     return 10

    def prepare_data(self):
        """Download data if needed.

        Do not use it to assign state (self.x = y).
        """
        pass

    def setup(self, stage: Optional[str] = None):
        """Load data. Set variables: `self.data_train`, `self.data_val`, `self.data_test`.

        This method is called by lightning with both `trainer.fit()` and `trainer.test()`, so be
        careful not to execute things like random split twice!
        """
        # sampler = SequentialSampler()
        if not self.data_train and not self.data_val and not self.data_test:
            self.data_train= SimpleDataset(
                db_path = self.db_path, 
                event_no_list = self.event_no_list[self.event_no_list % 10 > 1], #event_no_list_path = self.hparams.event_no_list_path,
                pulsemap = self.pulsemap,
                input_cols = self.input_cols,
                target_cols = self.target_cols,
                truth_table = self.truth_table,
            )
            self.data_val= SimpleDataset(
                db_path = self.db_path,
                event_no_list = self.event_no_list[self.event_no_list % 10 == 1], #event_no_list_path = self.hparams.event_no_list_path,
                pulsemap = self.pulsemap,
                input_cols = self.input_cols,
                target_cols = self.target_cols,
                truth_table = self.truth_table,
            )
            self.data_test= SimpleDataset(
                db_path = self.db_path,
                event_no_list = self.event_no_list[self.event_no_list% 10 == 0], #event_no_list_path = self.hparams.event_no_list_path,
                pulsemap = self.pulsemap,
                input_cols = self.input_cols,
                target_cols = self.target_cols,
                truth_table = self.truth_table,
            )


    def train_dataloader(self):
        return DataLoader(
            dataset=self.data_train,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            pin_memory=self.pin_memory,
            collate_fn= pad_collate,
            sampler=SequentialSampler(self.data_train)
        )

    def val_dataloader(self):
        return DataLoader(
            dataset=self.data_val,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            pin_memory=self.pin_memory,
            collate_fn= pad_collate,
            sampler=SequentialSampler(self.data_val)
        )

    def test_dataloader(self):
        return DataLoader(
            dataset=self.data_test,
            batch_size=self.batch_size,
            num_workers=self.num_workers,
            pin_memory=self.pin_memory,
            collate_fn= pad_collate,
            sampler=SequentialSampler(self.data_test)
        )

    def teardown(self, stage: Optional[str] = None):
        """Clean up after fit or test."""
        pass

    def state_dict(self):
        """Extra things to save to checkpoint."""
        return {}

    def load_state_dict(self, state_dict: Dict[str, Any]):
        """Things to do when loading checkpoint."""
        pass


dm=SimpleIceCubeSQLDatamodule()
dm.setup()
# Out:
# /groups/icecube/moust/miniconda3/envs/icet2/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: 'libc10_hip.so: cannot open shared object file: No such file or directory'If you don't plan on using image functionality from `torchvision.io`, you can ignore this warning. Otherwise, there might be something wrong with your environment. Did you have `libjpeg` or `libpng` installed before building `torchvision` from source?
#   warn(

# %%
class SQLiteTruthDataset(Dataset):
    def __init__(self, db_path, features_table, truth_table, features, truth, indices=None):
        self.db_path = db_path
        self.features_table = features_table
        self.truth_table = truth_table
        self.features = features
        self.truth = truth
        self.indices = indices
        self.conn = None
        self._establish_connection()
        if self.indices is None:
            self.indices = self._get_all_indices()

    def _establish_connection(self):
        self.conn = sqlite3.connect(self.db_path)

    def close_connection(self):
        if self.conn is not None:
            self.conn.close()

    def _get_all_indices(self):
        cursor = self.conn.cursor()
        cursor.execute(f"SELECT DISTINCT event_no FROM {self.features_table}")
        indices = [row[0] for row in cursor.fetchall()]
        return indices

    def query_table(self, table, columns, index):
        cursor = self.conn.cursor()
        cursor.execute(f"SELECT {','.join(columns)} FROM {table} WHERE event_no = ?", (index,))
        return cursor.fetchall()

    # def _create_graph(self, features, truth):
    #     x = torch.tensor([feature[1:] for feature in features], dtype=torch.float32)
    #     y = torch.tensor(truth[0][1:], dtype=torch.float32)
    #     return Data(x=x, y=y)
    
    # def _create_graph(self, features, truth):
    #     x = torch.tensor([feature[1:] for feature in features], dtype=torch.float32)
    #     if not truth:  # if truth list is empty
    #         print(f"No truth data found for index {index}")
    #     y = torch.tensor(truth[0][1:], dtype=torch.float32) if truth else torch.tensor([])
    #     return Data(x=x, y=y)

    def __len__(self):
        return len(self.indices)

    # def __getitem__(self, idx):
    #     index = self.indices[idx]
    #     features = self.query_table(self.features_table, self.features, index)
    #     truth = self.query_table(self.truth_table, self.truth, index)
    #     return self._create_graph(features, truth)
    def __getitem__(self, idx):
        index = self.indices[idx]
        features = self.query_table(self.features_table, self.features, index)
        truth = self.query_table(self.truth_table, self.truth, index)
        return self._create_graph(features, truth, index)

    def _create_graph(self, features, truth, index):
        x = torch.tensor([feature[1:] for feature in features], dtype=torch.float32)
        if not truth:  # if truth list is empty
            print(f"No truth data found for index {index}")
        y = torch.tensor(truth[0][1:], dtype=torch.float32) if truth else torch.tensor([])
        return Data(x=x, y=y)

# %%
event_no_path = "/groups/icecube/moust/work/IceCubeEncoderTransformer/notebooks/test_upgrade_pure_numu_selection_event_no.csv"
event_no = pd.read_csv(event_no_path,header=0,names=["event_no"],index_col=None)["event_no"].to_numpy()
print(event_no.shape)
dataset_test = SQLiteTruthDataset(
    db_path = "/groups/icecube/petersen/GraphNetDatabaseRepository/Upgrade_Data/sqlite3/dev_step4_upgrade_028_with_noise_dynedge_pulsemap_v3_merger_aftercrash.db",
    features_table = "SplitInIcePulses_dynedge_v2_Pulses",
    truth_table = "truth",
    features = ["dom_x", "dom_y", "dom_z", "dom_time", "rde"],
    truth = ["energy", "zenith", "azimuth", "pid"],
    # indices = event_no
)
# Out:
# (109882,)

# %%
for i in range(3):
    dataset_test[i]
# Out:
# No truth data found for index 6060832
# No truth data found for index 6060838
# No truth data found for index 6060840
# No truth data found for index 6060844
# No truth data found for index 6060849
# No truth data found for index 6060864
# No truth data found for index 6060865
# No truth data found for index 6060875
# No truth data found for index 6060880
# No truth data found for index 6060897
# No truth data found for index 6060900
# No truth data found for index 6060902
# No truth data found for index 6060909
# No truth data found for index 6060911
# No truth data found for index 6060917
# No truth data found for index 6060920
# No truth data found for index 6060927
# No truth data found for index 6060930
# No truth data found for index 6060934
# No truth data found for index 6060944
# No truth data found for index 6060950
# No truth data found for index 6060958
# No truth data found for index 6060971
# No truth data found for index 6060979
# No truth data found for index 6060988
# No truth data found for index 6060989
# No truth data found for index 6060997
# No truth data found for index 6061001
# No truth data found for index 6061013
# No truth data found for index 6061014
# No truth data found for index 6061020
# No truth data found for index 6061024
# No truth data found for index 6061044
# No truth data found for index 6061056
# No truth data found for index 6061061
# No truth data found for index 6061064
# No truth data found for index 6061069
# No truth data found for index 6061076
# No truth data found for index 6061078
# No truth data found for index 6061082
# No truth data found for index 6061098
# No truth data found for index 6061106
# No truth data found for index 6061118
# No truth data found for index 6061124
# No truth data found for index 6061136
# No truth data found for index 6061139
# No truth data found for index 6061144
# No truth data found for index 6061149
# No truth data found for index 6061155
# No truth data found for index 6061157
# No truth data found for index 6061162
# No truth data found for index 6061163
# No truth data found for index 6061178
# No truth data found for index 6061180
# No truth data found for index 6061182
# No truth data found for index 6061190
# No truth data found for index 6061191
# No truth data found for index 6061199
# No truth data found for index 6061200
# No truth data found for index 6061205
# No truth data found for index 6061218
# No truth data found for index 6061226
# No truth data found for index 6061232
# No truth data found for index 6061235
# No truth data found for index 6061239
# No truth data found for index 6061240
# No truth data found for index 6061242
# No truth data found for index 6061248
# No truth data found for index 6061249
# No truth data found for index 6061256
# No truth data found for index 6061260
# No truth data found for index 6061268
# No truth data found for index 6061276
# No truth data found for index 6061279
# No truth data found for index 6061284
# No truth data found for index 6061294
# No truth data found for index 6061301
# No truth data found for index 6061326
# No truth data found for index 6061327
# No truth data found for index 6061334
# No truth data found for index 6061338
# No truth data found for index 6061347
# No truth data found for index 6061354
# No truth data found for index 6061367
# No truth data found for index 6061374
# No truth data found for index 6061380
# No truth data found for index 6061386
# No truth data found for index 6061390
# No truth data found for index 6061395
# No truth data found for index 6061397
# No truth data found for index 6061400
# No truth data found for index 6061404
# No truth data found for index 6061405
# No truth data found for index 6061409
# No truth data found for index 6061412
# No truth data found for index 6061413
# No truth data found for index 6061419
# No truth data found for index 6061425
# No truth data found for index 6061439
# No truth data found for index 6061441
# No truth data found for index 6061442
# No truth data found for index 6061449
# No truth data found for index 6061451
# No truth data found for index 6061456
# No truth data found for index 6061465
# No truth data found for index 6061474
# No truth data found for index 6061475
# No truth data found for index 6061476
# No truth data found for index 6061494
# No truth data found for index 6061503
# No truth data found for index 6061504
# No truth data found for index 6061505
# No truth data found for index 6061512
# No truth data found for index 6061514
# No truth data found for index 6061517
# No truth data found for index 6061525
# No truth data found for index 6061530
# No truth data found for index 6061532
# No truth data found for index 6061536
# No truth data found for index 6061540
# No truth data found for index 6061542
# No truth data found for index 6061544
# No truth data found for index 6061550
# No truth data found for index 6061551
# No truth data found for index 6061557
# No truth data found for index 6061559
# No truth data found for index 6110818
# No truth data found for index 6110819
# No truth data found for index 6110828
# No truth data found for index 6110832
# No truth data found for index 6110834
# No truth data found for index 6110835
# No truth data found for index 6110841
# No truth data found for index 6110842
# No truth data found for index 6110851
# No truth data found for index 6110852
# No truth data found for index 6110854
# No truth data found for index 6110858
# No truth data found for index 6110860
# No truth data found for index 6110865
# No truth data found for index 6110868
# No truth data found for index 6110872
# No truth data found for index 6110875
# No truth data found for index 6110878
# No truth data found for index 6110883
# No truth data found for index 6110886
# No truth data found for index 6110891
# No truth data found for index 6110892
# No truth data found for index 6110895
# No truth data found for index 6110899
# No truth data found for index 6110903
# No truth data found for index 6110910
# No truth data found for index 6110911
# No truth data found for index 6110919
# No truth data found for index 6110923
# No truth data found for index 6110924
# No truth data found for index 6110925
# No truth data found for index 6110929
# No truth data found for index 6110931
# No truth data found for index 6110936
# No truth data found for index 6110938
# No truth data found for index 6110944
# No truth data found for index 6110946
# No truth data found for index 6110949
# No truth data found for index 6110953
# No truth data found for index 6110967
# No truth data found for index 6110972
# No truth data found for index 6110973
# No truth data found for index 6110980
# No truth data found for index 6110984
# No truth data found for index 6111007
# No truth data found for index 6111010
# No truth data found for index 6111018
# No truth data found for index 6111025
# No truth data found for index 6111032
# No truth data found for index 6111038
# No truth data found for index 6111040
# No truth data found for index 6111042
# No truth data found for index 6111053
# No truth data found for index 6111059
# No truth data found for index 6111061
# No truth data found for index 6111064
# No truth data found for index 6111068
# No truth data found for index 6111073
# No truth data found for index 6111082
# No truth data found for index 6111083
# No truth data found for index 6111093
# No truth data found for index 6111099
# No truth data found for index 6111100
# No truth data found for index 6111103
# No truth data found for index 6111107
# No truth data found for index 6111113
# No truth data found for index 6111117
# No truth data found for index 6111120
# No truth data found for index 6111123
# No truth data found for index 6111128
# No truth data found for index 6111131
# No truth data found for index 6111132
# No truth data found for index 6111134
# No truth data found for index 6111136
# No truth data found for index 6111137
# No truth data found for index 6111143
# No truth data found for index 6111147
# No truth data found for index 6111150
# No truth data found for index 6111155
# No truth data found for index 6111156
# No truth data found for index 6111158
# No truth data found for index 6111174
# No truth data found for index 6111178
# No truth data found for index 6111189
# No truth data found for index 6111193
# No truth data found for index 6111194
# No truth data found for index 6111201
# No truth data found for index 6111206
# No truth data found for index 6111209
# No truth data found for index 6111212
# No truth data found for index 6111218
# No truth data found for index 6111223
# No truth data found for index 6111228
# No truth data found for index 6111232
# No truth data found for index 6111238
# No truth data found for index 6111241
# No truth data found for index 6111244
# No truth data found for index 6111246
# No truth data found for index 6111251
# No truth data found for index 6111254
# No truth data found for index 6111259
# No truth data found for index 6111260
# No truth data found for index 6111273
# No truth data found for index 6111280
# No truth data found for index 6111289
# No truth data found for index 6111291

# %%
len(dm.data_test)
# Out:
# 53916

# %%
train_dl = dm.train_dataloader()
train_dl

# %%
features, truth, pad_mask = next(iter(train_dl))
# Out:
# [200, 200]

# %%
features.shape
# Out:
# torch.Size([2, 200, 8])

# %%
truth
# Out:
# tensor([ 66.5481, 112.6614])

# %%
pad_mask.sum()
# Out:
# tensor(0)

# %%
pad_mask
# Out:
# tensor([[False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False],
#         [False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False,
#          False, False, False, False, False, False, False, False, False, False]])
